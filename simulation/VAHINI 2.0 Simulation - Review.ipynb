# %% [markdown]
# <a href="https://colab.research.google.com/github/Blake2912/Vahini-2.0/blob/simulation-main/simulation/VAHINI%202.0%20Simulation%20-%20Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Open in Colab and Run for smooth functioning

# %% [markdown]
# ## Setup

# %%
# !pip install osmnx networkx shapely ipyleaflet ipywidgets -q

from time import sleep
import urllib.request
import osmnx as ox
import networkx as nx
from time import sleep
import pickle
import shapely
from shapely.geometry import Polygon
from ipyleaflet import Map, Marker, FullScreenControl, AwesomeIcon
from ipywidgets import interact
from time import sleep

py_url = "https://raw.githubusercontent.com/Blake2912/Vahini-2.0/simulation-main/simulation/mapSimulation.py"
urllib.request.urlretrieve(py_url, "mapSimulation.py")
from mapSimulation import InteractiveMap

pkl_url = "https://github.com/Blake2912/Vahini-2.0/raw/simulation-main/output/Trees_Final.pkl"
urllib.request.urlretrieve(pkl_url, "Trees_Final.pkl")
filename = "/content/Trees_Final.pkl"
with open(filename, "rb") as f:
    G = pickle.load(f)

# Plotting the Graph
fig, ax = ox.plot_graph(G)

# %% [markdown]
# ## Traverse through the Path

# %%
center = (12.96682, 77.71231)
m1 = InteractiveMap(center=center)
m1.add_trees(G)
m1.add_marker([G.nodes['basic_science']['y'], G.nodes['basic_science']['x']])

# %%
m1.display_map()
# Out:
# Map(center=[12.96682, 77.71231], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…

# %%
m1.traversal(G, 'basic_science', 'hostel_turn')

# %% [markdown]
# ## Battery Range Simulation

# %%
center = (12.96682, 77.71231)
m2 = InteractiveMap(center=center)
m2.add_trees(G)
m2.add_marker([G.nodes['t-4']['y'], G.nodes['t-4']['x']])

# %%
m2.display_map()
# Out:
# Map(center=[12.96682, 77.71231], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…

# %%
m2.battery_check(G, 't-4', 'basic_science', 200)

# %% [markdown]
# ## Water Level Simulation

# %%
center = (12.96682, 77.71231)
m3 = InteractiveMap(center=center)
m3.add_trees(G)
m3.add_marker([G.nodes['t-6']['y'], G.nodes['t-6']['x']])

# %%
m3.display_map()
# Out:
# Map(center=[12.96682, 77.71231], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…

# %%
m3.water_check(G, 't-6', 'basic_science', 15, 20)
